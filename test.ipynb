# %% [markdown]
# Fetch dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Q1flzyg1J8Z2OMweLXf3")
project = rf.workspace("weapon-mpr3p").project("ddr-dataset-yyvzp")
version = project.version(1)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
from sklearn.metrics import classification_report
import os
from pathlib import Path

model = YOLO(r"runs\classify\ddr-224-nano\weights\best.pt")

test_path = Path(dataset.location) / "test"

y_true = []
y_pred = []

# Loop over class folders
for class_id, class_name in enumerate(sorted(os.listdir(test_path))):
    class_folder = test_path / class_name
    
    for img_path in class_folder.glob("*.*"):
        result = model(img_path, verbose=False)[0]
        
        pred_class = result.probs.top1  # predicted index
        
        y_pred.append(pred_class)
        y_true.append(class_id)

# Print metrics
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.7847    0.9020    0.8393       602
#            1     0.0000    0.0000    0.0000        61
#            2     0.6918    0.7370    0.7137       460
#            3     0.6250    0.1786    0.2778        28
#            4     0.7966    0.5529    0.6528        85
#            5     0.8667    0.7712    0.8161       118
#
#     accuracy                         0.7570      1354
#    macro avg     0.6275    0.5236    0.5499      1354
# weighted avg     0.7224    0.7570    0.7335      1354
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
